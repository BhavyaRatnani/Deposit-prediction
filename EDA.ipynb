# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data=pd.read_csv('vanilla.csv')

# %%
data
# Out:
#       age           job   marital  education default  balance housing loan  \
# 0      43    technician   married  secondary      no      297     yes   no
# 1      35  entrepreneur   married    primary      no        0      no  yes
# 2      32    technician    single   tertiary      no     1150      no   no
# 3      61       retired   married   tertiary      no     2557     yes   no
# 4      25        admin.    single  secondary      no      507     yes   no
# ...   ...           ...       ...        ...     ...      ...     ...  ...
# 3995   57      services  divorced    primary      no     1920      no   no
# 3996   30    technician   married  secondary      no      776      no   no
# 3997   31   blue-collar    single  secondary      no        0     yes   no
# 3998   31   blue-collar   married  secondary      no     1407     yes   no
# 3999   32    management    single   tertiary      no     3050     yes   no
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4000 non-null   int64
#  1   job        4000 non-null   object
#  2   marital    4000 non-null   object
#  3   education  4000 non-null   object
#  4   default    4000 non-null   object
#  5   balance    4000 non-null   int64
#  6   housing    4000 non-null   object
#  7   loan       4000 non-null   object
#  8   contact    4000 non-null   object
#  9   day        4000 non-null   int64
#  10  duration   4000 non-null   int64
#  11  campaign   4000 non-null   int64
#  12  pdays      4000 non-null   int64
#  13  previous   4000 non-null   int64
#  14  poutcome   4000 non-null   object
#  15  y          4000 non-null   object
# dtypes: int64(7), object(9)
# memory usage: 500.1+ KB

# %%
data.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4000.000000   4000.000000  4000.000000  4000.000000  4000.000000
# mean     40.954000   1339.322250    15.619500   287.603500     2.729750
# std      10.698645   2626.811846     8.367241   284.355168     3.100261
# min      18.000000  -2082.000000     1.000000     5.000000     1.000000
# 25%      32.000000     78.000000     8.000000   111.000000     1.000000
# 50%      39.000000    468.000000    15.500000   190.000000     2.000000
# 75%      48.000000   1450.250000    21.000000   356.000000     3.000000
# max      85.000000  34646.000000    31.000000  2653.000000    51.000000
#
#              pdays     previous
# count  4000.000000  4000.000000
# mean     41.546000     0.578500
# std     100.002337     1.733231
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     595.000000    29.000000

# %%
data.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
data.isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
data.select_dtypes(include=['object']).columns
categ_var=['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact','poutcome', 'y']

# %%
data.select_dtypes(include=['int64']).columns
nume_var=['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']

# %%
data.isnull().sum()*100/len(data)
# Out:
# age          0.0
# job          0.0
# marital      0.0
# education    0.0
# default      0.0
# balance      0.0
# housing      0.0
# loan         0.0
# contact      0.0
# day          0.0
# duration     0.0
# campaign     0.0
# pdays        0.0
# previous     0.0
# poutcome     0.0
# y            0.0
# dtype: float64

# %%
sns.countplot(x=data['y'])

# %%
for i in categ_var:
  plt.figure(figsize=(20,8))
  ax=sns.countplot(x=data[i])
  #label_values(ax, spacing=-15)
  plt.show()

# %%
for i in categ_var:
    plt.figure(figsize=(20,8))
    ax=sns.catplot(x='y', col=i, kind='count', data= data)
    #label_values(ax, spacing=-15)
plt.show()

# %%
for i in categ_var:
    print(data.groupby(['y',i]).size())
# Out:
# y    job
# no   admin.           378
#      blue-collar      695
#      entrepreneur     104
#      housemaid        104
#      management       649
#      retired          135
#      self-employed    138
#      services         278
#      student           47
#      technician       519
#      unemployed       106
#      unknown           19
# yes  admin.           106
#      blue-collar      104
#      entrepreneur      24
#      housemaid         20
#      management       199
#      retired           79
#      self-employed     32
#      services          61
#      student           34
#      technician       126
#      unemployed        36
#      unknown            7
# dtype: int64
# y    marital
# no   divorced     363
#      married     1910
#      single       899
# yes  divorced     103
#      married      420
#      single       305
# dtype: int64
# y    education
# no   primary       511
#      secondary    1662
#      tertiary      876
#      unknown       123
# ...

# %% [markdown]
# Continuous variables

# %%
data[nume_var]
# Out:
#       age  balance  day  duration  campaign  pdays  previous
# 0      43      297   14       119         3     -1         0
# 1      35        0   21        26        10     -1         0
# 2      32     1150    8        31         2     -1         0
# 3      61     2557   10       158         2     92         5
# 4      25      507   15       832         1    367         3
# ...   ...      ...  ...       ...       ...    ...       ...
# 3995   57     1920   19        77         2     -1         0
# 3996   30      776   30       861         2     -1         0
# 3997   31        0    6       273         2     -1         0
# 3998   31     1407    6       142         3     -1         0
# 3999   32     3050   23       298         1     -1         0
#
# [4000 rows x 7 columns]

# %%
for i in nume_var:
  plt.figure(figsize=(10,4))
  ax=sns.distplot(x=data[i])
  plt.xlabel(i)
  plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
for i in nume_var:
  plt.figure(figsize=(20,10))
  #ax=sns.boxplot(x="y", y= data[i], data=data)
  ax=sns.boxplot(data[i])
  plt.xlabel(i)
  plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
corr = data.corr()
sns.heatmap(corr,annot=True,cmap='Reds')
